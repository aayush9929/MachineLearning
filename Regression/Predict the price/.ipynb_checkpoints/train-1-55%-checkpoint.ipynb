# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("dataset/train.csv")

# %%
data
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 0     BRAE2NF6JA5GUEXG      37.0  2015-08-22 18:36:12.000                2
# 1     TUNE8SFB6RJN2HSD      38.0  2016-03-27 21:19:13.000               24
# 2     BRAEAR7WZPQGPBZU       9.0  2015-08-18 19:25:22.000              447
# 3     WATDZ2ZQ8JPDHCTJ      50.0  2016-03-28 21:53:01.000               23
# 4     JWSEBUKYQPMBZ3RK       7.0  2016-03-29 22:58:53.000               63
# ...                ...       ...                      ...              ...
# 6363  WATE7VE2D62VEKW8      17.0  2016-03-28 19:55:43.000               24
# 6364  SHOEF9G8Z4ZXF6WE      21.0  2015-02-11 15:09:26.000               55
# 6365  PBXEB9ZQ7HHCFXYG      36.0  2015-11-19 17:29:21.000              358
# 6366  NKCEAGXHRYTNTMG7      27.0  2015-12-08 04:19:33.000              452
# 6367  CAGE53FSAFWZRHFF      11.0  2016-01-20 19:45:35.000               58
#
# ...

# %%
data.shape
# Out:
# (6368, 15)

# %%
data.dtypes
# Out:
# Product_id           object
# Stall_no            float64
# instock_date         object
# Market_Category       int64
# Customer_name        object
# Loyalty_customer     object
# Product_Category     object
# Grade                 int64
# Demand                int64
# Discount_avail      float64
# charges_1           float64
# charges_2 (%)       float64
# Minimum_price       float64
# Maximum_price       float64
# Selling_Price       float64
# dtype: object

# %%
data['instock_date'] = pd.to_datetime(data['instock_date'])

# %%
data.dtypes
# Out:
# Product_id                  object
# Stall_no                   float64
# instock_date        datetime64[ns]
# Market_Category              int64
# Customer_name               object
# Loyalty_customer            object
# Product_Category            object
# Grade                        int64
# Demand                       int64
# Discount_avail             float64
# charges_1                  float64
# charges_2 (%)              float64
# Minimum_price              float64
# Maximum_price              float64
# Selling_Price              float64
# dtype: object

# %%
data['year'] = data['instock_date'].dt.year

# %%
data['month'] = data['instock_date'].dt.month

# %%
data.head()
# Out:
#          Product_id  Stall_no        instock_date  Market_Category  \
# 0  BRAE2NF6JA5GUEXG      37.0 2015-08-22 18:36:12                2
# 1  TUNE8SFB6RJN2HSD      38.0 2016-03-27 21:19:13               24
# 2  BRAEAR7WZPQGPBZU       9.0 2015-08-18 19:25:22              447
# 3  WATDZ2ZQ8JPDHCTJ      50.0 2016-03-28 21:53:01               23
# 4  JWSEBUKYQPMBZ3RK       7.0 2016-03-29 22:58:53               63
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0      Lillyann              Yes          Fashion      1      68
# 1         Klynn              Yes          Fashion      0      51
# 2         Ridge              Yes       Child_care      0      10
# 3         Abran              Yes      Educational      2      48
# 4        Dustyn              Yes           Repair      1      35
#
#    Discount_avail  charges_1  charges_2 (%)  Minimum_price  Maximum_price  \
# 0             0.0      376.0           11.0         2983.0         4713.0
# ...

# %%
data.drop(columns =['instock_date'],inplace=True)

# %%
data.head()
# Out:
#          Product_id  Stall_no  Market_Category Customer_name Loyalty_customer  \
# 0  BRAE2NF6JA5GUEXG      37.0                2      Lillyann              Yes
# 1  TUNE8SFB6RJN2HSD      38.0               24         Klynn              Yes
# 2  BRAEAR7WZPQGPBZU       9.0              447         Ridge              Yes
# 3  WATDZ2ZQ8JPDHCTJ      50.0               23         Abran              Yes
# 4  JWSEBUKYQPMBZ3RK       7.0               63        Dustyn              Yes
#
#   Product_Category  Grade  Demand  Discount_avail  charges_1  charges_2 (%)  \
# 0          Fashion      1      68             0.0      376.0           11.0
# 1          Fashion      0      51             0.0      397.0           12.0
# 2       Child_care      0      10             0.0      250.0            9.0
# 3      Educational      2      48             0.0      144.0           13.0
# 4           Repair      1      35             1.0      211.0            4.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6368 entries, 0 to 6367
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_id        6368 non-null   object
#  1   Stall_no          6363 non-null   float64
#  2   Market_Category   6368 non-null   int64
#  3   Customer_name     6157 non-null   object
#  4   Loyalty_customer  6368 non-null   object
#  5   Product_Category  6368 non-null   object
#  6   Grade             6368 non-null   int64
#  7   Demand            6368 non-null   int64
#  8   Discount_avail    6330 non-null   float64
#  9   charges_1         6170 non-null   float64
#  10  charges_2 (%)     6163 non-null   float64
#  11  Minimum_price     6330 non-null   float64
#  12  Maximum_price     6025 non-null   float64
#  13  Selling_Price     6327 non-null   float64
#  14  year              6368 non-null   int64
#  15  month             6368 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lo_cu = LabelEncoder()
pr_ca = LabelEncoder()

# %%
data['loyalty_customer_encoding'] = lo_cu.fit_transform(data['Loyalty_customer'])
data['product_category_encoding'] = pr_ca.fit_transform(data['Product_Category'])

# %%
data.head()
# Out:
#          Product_id  Stall_no  Market_Category Customer_name Loyalty_customer  \
# 0  BRAE2NF6JA5GUEXG      37.0                2      Lillyann              Yes
# 1  TUNE8SFB6RJN2HSD      38.0               24         Klynn              Yes
# 2  BRAEAR7WZPQGPBZU       9.0              447         Ridge              Yes
# 3  WATDZ2ZQ8JPDHCTJ      50.0               23         Abran              Yes
# 4  JWSEBUKYQPMBZ3RK       7.0               63        Dustyn              Yes
#
#   Product_Category  Grade  Demand  Discount_avail  charges_1  charges_2 (%)  \
# 0          Fashion      1      68             0.0      376.0           11.0
# 1          Fashion      0      51             0.0      397.0           12.0
# 2       Child_care      0      10             0.0      250.0            9.0
# 3      Educational      2      48             0.0      144.0           13.0
# 4           Repair      1      35             1.0      211.0            4.0
#
# ...

# %%
data.drop(columns=['Customer_name','Loyalty_customer','Product_Category'],inplace=True)

# %%
data.head()
# Out:
#          Product_id  Stall_no  Market_Category  Grade  Demand  Discount_avail  \
# 0  BRAE2NF6JA5GUEXG      37.0                2      1      68             0.0
# 1  TUNE8SFB6RJN2HSD      38.0               24      0      51             0.0
# 2  BRAEAR7WZPQGPBZU       9.0              447      0      10             0.0
# 3  WATDZ2ZQ8JPDHCTJ      50.0               23      2      48             0.0
# 4  JWSEBUKYQPMBZ3RK       7.0               63      1      35             1.0
#
#    charges_1  charges_2 (%)  Minimum_price  Maximum_price  Selling_Price  \
# 0      376.0           11.0         2983.0         4713.0    4185.947700
# 1      397.0           12.0         7495.0        10352.0    9271.490256
# 2      250.0            9.0         5752.0         7309.0    6785.701362
# 3      144.0           13.0         5090.0        20814.0   13028.917824
# 4      211.0            4.0         2430.0         9261.0     906.553935
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6368 entries, 0 to 6367
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Product_id                 6368 non-null   object
#  1   Stall_no                   6363 non-null   float64
#  2   Market_Category            6368 non-null   int64
#  3   Grade                      6368 non-null   int64
#  4   Demand                     6368 non-null   int64
#  5   Discount_avail             6330 non-null   float64
#  6   charges_1                  6170 non-null   float64
#  7   charges_2 (%)              6163 non-null   float64
#  8   Minimum_price              6330 non-null   float64
#  9   Maximum_price              6025 non-null   float64
#  10  Selling_Price              6327 non-null   float64
#  11  year                       6368 non-null   int64
#  12  month                      6368 non-null   int64
# ...

# %%
data.corr()
# Out:
#                            Stall_no  Market_Category     Grade    Demand  \
# Stall_no                   1.000000        -0.006145 -0.003449  0.004302
# Market_Category           -0.006145         1.000000 -0.036346 -0.018800
# Grade                     -0.003449        -0.036346  1.000000  0.010107
# Demand                     0.004302        -0.018800  0.010107  1.000000
# Discount_avail            -0.019656        -0.003306 -0.025232  0.010230
# charges_1                 -0.010224         0.019009 -0.025316 -0.007370
# charges_2 (%)             -0.004745         0.024154 -0.016644  0.017653
# Minimum_price              0.000123         0.194787 -0.079583  0.010283
# Maximum_price              0.008443         0.134257  0.164350  0.003987
# Selling_Price              0.011733         0.138711  0.086450 -0.000601
# year                       0.014395        -0.153502  0.026413 -0.008687
# month                     -0.014531         0.088342 -0.032201  0.013748
# ...

# %%
data.drop(columns=['Discount_avail','charges_2 (%)'],inplace=True)

# %%
data.head()
# Out:
#          Product_id  Stall_no  Market_Category  Grade  Demand  charges_1  \
# 0  BRAE2NF6JA5GUEXG      37.0                2      1      68      376.0
# 1  TUNE8SFB6RJN2HSD      38.0               24      0      51      397.0
# 2  BRAEAR7WZPQGPBZU       9.0              447      0      10      250.0
# 3  WATDZ2ZQ8JPDHCTJ      50.0               23      2      48      144.0
# 4  JWSEBUKYQPMBZ3RK       7.0               63      1      35      211.0
#
#    Minimum_price  Maximum_price  Selling_Price  year  month  \
# 0         2983.0         4713.0    4185.947700  2015      8
# 1         7495.0        10352.0    9271.490256  2016      3
# 2         5752.0         7309.0    6785.701362  2015      8
# 3         5090.0        20814.0   13028.917824  2016      3
# 4         2430.0         9261.0     906.553935  2016      3
#
#    loyalty_customer_encoding  product_category_encoding
# 0                          1                          3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6368 entries, 0 to 6367
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Product_id                 6368 non-null   object
#  1   Stall_no                   6363 non-null   float64
#  2   Market_Category            6368 non-null   int64
#  3   Grade                      6368 non-null   int64
#  4   Demand                     6368 non-null   int64
#  5   charges_1                  6170 non-null   float64
#  6   Minimum_price              6330 non-null   float64
#  7   Maximum_price              6025 non-null   float64
#  8   Selling_Price              6327 non-null   float64
#  9   year                       6368 non-null   int64
#  10  month                      6368 non-null   int64
#  11  loyalty_customer_encoding  6368 non-null   int32
#  12  product_category_encoding  6368 non-null   int32
# ...

# %%
data.shape
# Out:
# (6368, 13)

# %%
for column in data.columns:
    if data[column].isnull().values.any():
        print(column,data[column].isnull().sum())
# Out:
# Stall_no 5
# charges_1 198
# Minimum_price 38
# Maximum_price 343
# Selling_Price 41

# %%
data.drop(data[data['Stall_no'].isnull()].index, inplace = True)

# %%
for column in data.columns:
    if data[column].isnull().values.any():
        print(column,data[column].isnull().sum())
# Out:
# charges_1 198
# Minimum_price 38
# Maximum_price 342
# Selling_Price 41

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6363 entries, 0 to 6367
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Product_id                 6363 non-null   object
#  1   Stall_no                   6363 non-null   float64
#  2   Market_Category            6363 non-null   int64
#  3   Grade                      6363 non-null   int64
#  4   Demand                     6363 non-null   int64
#  5   charges_1                  6165 non-null   float64
#  6   Minimum_price              6325 non-null   float64
#  7   Maximum_price              6021 non-null   float64
#  8   Selling_Price              6322 non-null   float64
#  9   year                       6363 non-null   int64
#  10  month                      6363 non-null   int64
#  11  loyalty_customer_encoding  6363 non-null   int32
#  12  product_category_encoding  6363 non-null   int32
# ...

# %%
data.Market_Category.unique()
# Out:
# array([  2,  24, 447,  23,  63, 162, 462, 156, 275,   3, 268, 188, 186,
#        358,   1, 294, 456, 137, 250, 451, 198, 211, 283, 236, 165, 101,
#        423,  14,  11, 443,  58,  62,   0,  55, 469, 350,  27, 320,  38,
#        441, 235,  85, 230, 111,  65, 103, 110,  83,  93, 131, 452, 205,
#         60, 199,  73, 255,  13, 192, 407, 116,  97, 115,  37, 113, 100,
#         74,  57,  70,   9, 444, 146, 204, 367, 114,  79,  80, 121,  39,
#        445, 459, 463, 454, 141, 216, 231, 124, 152, 471,  61, 234, 448,
#        315, 164, 446, 220, 175, 191, 123, 449, 108, 104, 437, 455,  51,
#        450, 190, 397,  76, 453, 256,  94,  12, 173,  17, 403, 163, 167,
#         40, 149, 430, 179, 460, 458, 416, 150,  69,  98,  30, 436, 118,
#        106, 166, 227, 326, 389, 209, 138, 202, 112, 132, 177,  90, 468,
#         99,  36, 376, 144, 467, 147,  78, 249,  20, 224,  45,  87, 127,
#        105, 129, 214,  15, 210,  43, 457, 470,  41, 151,  10, 168,  52,
# ...

# %%
#print(data.loc[(data['charges_1'].isnull()) &  (data['product_category_encoding']==1)])
#print(data.loc[(data['product_category_encoding']==1)].median())
#print(data.product_category_encoding.unique())}
#data.loc[(data['product_category_encoding']==product_id)].median()['charges_1']
for product_id in data.product_category_encoding.unique():
    #print(data.loc[(data['charges_1'].isnull()) &  (data['product_category_encoding']==product_id)])
    #print(product_id,data.loc[(data['product_category_encoding']==product_id)].median()['charges_1'])
    #print(data.loc[(data['product_category_encoding']==product_id)].median()['charges_1'])
    replace_value = data.loc[(data['product_category_encoding']==product_id)].median()['charges_1']
    print(replace_value)
    data.loc[(data['product_category_encoding']==product_id),('charges_1')]=data.loc[(data['product_category_encoding']==product_id),('charges_1')].fillna(replace_value)
    print(data.loc[(data['charges_1'].isnull()) &  (data['product_category_encoding']==product_id)])
    
#data.loc[(data['product_category_encoding']==1)].median()['charges_1']
# Out:
# 374.0
# Empty DataFrame
# Columns: [Product_id, Stall_no, Market_Category, Grade, Demand, charges_1, Minimum_price, Maximum_price, Selling_Price, year, month, loyalty_customer_encoding, product_category_encoding]
# Index: []
# 300.0
# Empty DataFrame
# Columns: [Product_id, Stall_no, Market_Category, Grade, Demand, charges_1, Minimum_price, Maximum_price, Selling_Price, year, month, loyalty_customer_encoding, product_category_encoding]
# Index: []
# 136.0
# Empty DataFrame
# Columns: [Product_id, Stall_no, Market_Category, Grade, Demand, charges_1, Minimum_price, Maximum_price, Selling_Price, year, month, loyalty_customer_encoding, product_category_encoding]
# Index: []
# 247.5
# Empty DataFrame
# Columns: [Product_id, Stall_no, Market_Category, Grade, Demand, charges_1, Minimum_price, Maximum_price, Selling_Price, year, month, loyalty_customer_encoding, product_category_encoding]
# Index: []
# 559.0
# Empty DataFrame
# ...

# %%
data.corr().sort_values(['charges_1'])
# Out:
#                            Stall_no  Market_Category     Grade    Demand  \
# Grade                     -0.003449        -0.036043  1.000000  0.010385
# year                       0.014395        -0.153281  0.026097 -0.008413
# Stall_no                   1.000000        -0.006145 -0.003449  0.004302
# Demand                     0.004302        -0.020123  0.010385  1.000000
# loyalty_customer_encoding  0.007605         0.033846  0.026704  0.005171
# month                     -0.014531         0.087910 -0.031717  0.013295
# Maximum_price              0.008443         0.134056  0.164370  0.003767
# Market_Category           -0.006145         1.000000 -0.036043 -0.020123
# Minimum_price              0.000123         0.194368 -0.079528  0.009840
# Selling_Price              0.011733         0.138419  0.086586 -0.000883
# product_category_encoding -0.011059        -0.001081  0.010482 -0.021505
# charges_1                 -0.010224         0.019285 -0.025316 -0.007228
#
# ...

# %%
data.head()
# Out:
#          Product_id  Stall_no  Market_Category  Grade  Demand  charges_1  \
# 0  BRAE2NF6JA5GUEXG      37.0                2      1      68      376.0
# 1  TUNE8SFB6RJN2HSD      38.0               24      0      51      397.0
# 2  BRAEAR7WZPQGPBZU       9.0              447      0      10      250.0
# 3  WATDZ2ZQ8JPDHCTJ      50.0               23      2      48      144.0
# 4  JWSEBUKYQPMBZ3RK       7.0               63      1      35      211.0
#
#    Minimum_price  Maximum_price  Selling_Price  year  month  \
# 0         2983.0         4713.0    4185.947700  2015      8
# 1         7495.0        10352.0    9271.490256  2016      3
# 2         5752.0         7309.0    6785.701362  2015      8
# 3         5090.0        20814.0   13028.917824  2016      3
# 4         2430.0         9261.0     906.553935  2016      3
#
#    loyalty_customer_encoding  product_category_encoding
# 0                          1                          3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6363 entries, 0 to 6367
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Product_id                 6363 non-null   object
#  1   Stall_no                   6363 non-null   float64
#  2   Market_Category            6363 non-null   int64
#  3   Grade                      6363 non-null   int64
#  4   Demand                     6363 non-null   int64
#  5   charges_1                  6363 non-null   float64
#  6   Minimum_price              6325 non-null   float64
#  7   Maximum_price              6021 non-null   float64
#  8   Selling_Price              6322 non-null   float64
#  9   year                       6363 non-null   int64
#  10  month                      6363 non-null   int64
#  11  loyalty_customer_encoding  6363 non-null   int32
#  12  product_category_encoding  6363 non-null   int32
# ...

# %%
data.plot(y='charges_1',x='product_category_encoding',style='o')
# Out:
# <AxesSubplot:xlabel='product_category_encoding'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6363 entries, 0 to 6367
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Product_id                 6363 non-null   object
#  1   Stall_no                   6363 non-null   float64
#  2   Market_Category            6363 non-null   int64
#  3   Grade                      6363 non-null   int64
#  4   Demand                     6363 non-null   int64
#  5   charges_1                  6363 non-null   float64
#  6   Minimum_price              6325 non-null   float64
#  7   Maximum_price              6021 non-null   float64
#  8   Selling_Price              6322 non-null   float64
#  9   year                       6363 non-null   int64
#  10  month                      6363 non-null   int64
#  11  loyalty_customer_encoding  6363 non-null   int32
#  12  product_category_encoding  6363 non-null   int32
# ...

# %%
data.corr().sort_values(['Minimum_price'])
# Out:
#                            Stall_no  Market_Category     Grade    Demand  \
# Grade                     -0.003449        -0.036043  1.000000  0.010385
# month                     -0.014531         0.087910 -0.031717  0.013295
# Stall_no                   1.000000        -0.006145 -0.003449  0.004302
# product_category_encoding -0.011059        -0.001081  0.010482 -0.021505
# Demand                     0.004302        -0.020123  0.010385  1.000000
# charges_1                 -0.008586         0.019176 -0.025778 -0.004931
# year                       0.014395        -0.153281  0.026097 -0.008413
# loyalty_customer_encoding  0.007605         0.033846  0.026704  0.005171
# Market_Category           -0.006145         1.000000 -0.036043 -0.020123
# Selling_Price              0.011733         0.138419  0.086586 -0.000883
# Maximum_price              0.008443         0.134056  0.164370  0.003767
# Minimum_price              0.000123         0.194368 -0.079528  0.009840
#
# ...

# %%
# made it for max price, min price,selling price
for market_category in data.Market_Category.unique():
    replace_value = data.loc[(data['Market_Category']==market_category)].median()['Selling_Price']
    print(replace_value)
    data.loc[(data['Market_Category']==market_category),('Selling_Price')]=data.loc[(data['Market_Category']==market_category),('Selling_Price')].fillna(replace_value)
    print(data.loc[(data['Selling_Price'].isnull()) &  (data['Market_Category']==market_category)])
# Out:
# 5820.637463999999
# Empty DataFrame
# Columns: [Product_id, Stall_no, Market_Category, Grade, Demand, charges_1, Minimum_price, Maximum_price, Selling_Price, year, month, loyalty_customer_encoding, product_category_encoding]
# Index: []
# 5617.967824
# Empty DataFrame
# Columns: [Product_id, Stall_no, Market_Category, Grade, Demand, charges_1, Minimum_price, Maximum_price, Selling_Price, year, month, loyalty_customer_encoding, product_category_encoding]
# Index: []
# 5019.908775
# Empty DataFrame
# Columns: [Product_id, Stall_no, Market_Category, Grade, Demand, charges_1, Minimum_price, Maximum_price, Selling_Price, year, month, loyalty_customer_encoding, product_category_encoding]
# Index: []
# 4122.6574485
# Empty DataFrame
# Columns: [Product_id, Stall_no, Market_Category, Grade, Demand, charges_1, Minimum_price, Maximum_price, Selling_Price, year, month, loyalty_customer_encoding, product_category_encoding]
# Index: []
# 6886.143
# Empty DataFrame
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6363 entries, 0 to 6367
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Product_id                 6363 non-null   object
#  1   Stall_no                   6363 non-null   float64
#  2   Market_Category            6363 non-null   int64
#  3   Grade                      6363 non-null   int64
#  4   Demand                     6363 non-null   int64
#  5   charges_1                  6363 non-null   float64
#  6   Minimum_price              6363 non-null   float64
#  7   Maximum_price              6361 non-null   float64
#  8   Selling_Price              6363 non-null   float64
#  9   year                       6363 non-null   int64
#  10  month                      6363 non-null   int64
#  11  loyalty_customer_encoding  6363 non-null   int32
#  12  product_category_encoding  6363 non-null   int32
# ...

# %%
a=data['Maximum_price'].median()
data['Maximum_price']=data['Maximum_price'].fillna(a)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6363 entries, 0 to 6367
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Product_id                 6363 non-null   object
#  1   Stall_no                   6363 non-null   float64
#  2   Market_Category            6363 non-null   int64
#  3   Grade                      6363 non-null   int64
#  4   Demand                     6363 non-null   int64
#  5   charges_1                  6363 non-null   float64
#  6   Minimum_price              6363 non-null   float64
#  7   Maximum_price              6363 non-null   float64
#  8   Selling_Price              6363 non-null   float64
#  9   year                       6363 non-null   int64
#  10  month                      6363 non-null   int64
#  11  loyalty_customer_encoding  6363 non-null   int32
#  12  product_category_encoding  6363 non-null   int32
# ...

# %%
#creating train data
X=data.drop(columns=['Product_id','Selling_Price']).values
y=data['Selling_Price'].values

# %%
X.shape
# Out:
# (6363, 11)

# %%
y.shape
# Out:
# (6363,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=82)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,reg.predict(X_test))#99.556
# Out:
# 0.7021405752984724

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
lr=RandomForestRegressor(max_depth=59)#30,99.5880

# %%
lr.fit(X_train,y_train)#19,99.577
# Out:
# RandomForestRegressor(max_depth=59)

# %%
r2_score(y_test,lr.predict(X_test))#99.556
# Out:
# 0.666478055945487

# %%
lr.score(X, y)
# Out:
# 0.9130272468231168

# %%
import seaborn as sns
sns.boxplot(data['charges_1'])
# Out:
# H:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='charges_1'>

# %%
data[data['charges_1']>550]
# Out:
#             Product_id  Stall_no  Market_Category  Grade  Demand  charges_1  \
# 5     SHIECAYW3VZWGZGX      23.0              162      1      49      633.0
# 39    SHIEBZY34GZUFZQX      21.0              443      0      40      613.0
# 71    BNGEB467ZXZZ4HWS      24.0               58      1      39      646.0
# 73    TOPEDHATHJRHTNMP      13.0              235      2      64      587.0
# 102   WATDXFGTKC3HBKWM       7.0               24      0      72      585.0
# ...                ...       ...              ...    ...     ...        ...
# 6355  BRAEBUHTTCZKDPTC      20.0               65      0      81      564.0
# 6356  TOPDYAZZNRQMQABE      48.0               68      2      13      640.0
# 6360  SNDE3UG82VHVW5EX      32.0               24      0      83      643.0
# 6363  WATE7VE2D62VEKW8      17.0               24      0      47      614.0
# 6367  CAGE53FSAFWZRHFF      11.0               58      0      94      614.0
#
# ...

# %%
sns.boxplot(data['Maximum_price'])
# Out:
# H:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Maximum_price'>

# %%
sns.boxplot(data['Minimum_price'])
# Out:
# H:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Minimum_price'>

# %%
sns.boxplot(data['Selling_Price'])
# Out:
# H:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Selling_Price'>
